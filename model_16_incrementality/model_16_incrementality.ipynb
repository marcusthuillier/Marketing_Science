# %% [markdown]
# # Model 16 - Transfer Incrementality Testing
# **Discipline:** Growth DS
# **Question:** Did a major transfer signing cause team improvement — or were they already improving before the player arrived?
# **Method:** Synthetic control + CausalImpact to quantify incremental impact of individual transfers

# %% [markdown]
# ## 0. Imports & Setup

# %%
import warnings
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

warnings.filterwarnings('ignore')
pd.set_option('display.max_columns', 50)

RANDOM_STATE = 42
OUTPUTS_DIR = 'outputs/'
print('All imports successful.')

# %% [markdown]
# ## 1. Event Selection
# 5 high-profile transfers: clear successes, clear failures, ambiguous. Record exact signing date and debut.

# %%
# TODO: Implement Event Selection
# See README.md for full step-by-step instructions

# %% [markdown]
# ## 2. Data Collection
# Team xG per match for buying club. 20 matches pre-signing, 20 post-debut. Control: similar teams who didn't sign.

# %%
# TODO: Implement Data Collection
# See README.md for full step-by-step instructions

# %% [markdown]
# ## 3. Synthetic Control
# 3-5 donor teams similar to treatment pre-signing. Optimally weight donors to replicate pre-signing trajectory.

# %%
# TODO: Implement Synthetic Control
# See README.md for full step-by-step instructions

# %% [markdown]
# ## 4. CausalImpact
# Actual post-debut vs synthetic control. Cumulative incremental xG. Confidence intervals.

# %%
# TODO: Implement CausalImpact
# See README.md for full step-by-step instructions

# %% [markdown]
# ## 5. Heterogeneity Analysis
# Do expensive signings have higher incrementality? Do signings for struggling teams have higher uplift?

# %%
# TODO: Implement Heterogeneity Analysis
# See README.md for full step-by-step instructions

# %% [markdown]
# ## 6. Findings
# Many 'successful' transfers not as incremental as perceived. Some 'failed' transfers had positive incrementality.

# %%
# TODO: Implement Findings
# See README.md for full step-by-step instructions

# %% [markdown]
# ## Notes & Findings
# <!-- Fill in after running the notebook -->
#
# **Key finding:**
# _
#
# **Surprising result:**
# _
#
# **Key angle:**
# _Incrementality testing is how growth teams avoid fooling themselves. I applied it to football transfers. Some £100M signings had near-zero incremental impact._
