# %% [markdown]
# # Model 10 - Transfer Sentiment Analysis
# **Discipline:** Marketing DS + Product DS
# **Question:** How does fan sentiment on Reddit shift after major transfer announcements — and does sentiment predict short-term match performance?
# **Method:** VADER + DistilBERT sentiment scoring + BERTopic topic modeling + correlation analysis
# **LinkedIn Hook:** I analyzed Reddit after a blockbuster transfer announcement. Fan sentiment collapsed — then the team won 3 straight. The data is more interesting than the narrative.

# %% [markdown]
# ## 0. Imports & Setup

# %%
import warnings
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

warnings.filterwarnings('ignore')
pd.set_option('display.max_columns', 50)

RANDOM_STATE = 42
OUTPUTS_DIR = 'outputs/'
print('All imports successful.')

# %% [markdown]
# ## 1. Event Selection
# Choose 3-5 major transfers or match results. Define time windows: 48h before and 72h after each event.

# %%
# TODO: Implement Event Selection
# See README.md for full step-by-step instructions

# %% [markdown]
# ## 2. Data Collection
# Register PRAW app at reddit.com/prefs/apps. Pull r/soccer or team subreddit: title, body, upvotes, timestamp. ~500-2000 posts per event window.

# %%
# TODO: Implement Data Collection
# See README.md for full step-by-step instructions

# %% [markdown]
# ## 3. Preprocessing
# Remove URLs, usernames. Lowercase. Keep timestamp, text, upvote_score.

# %%
# TODO: Implement Preprocessing
# See README.md for full step-by-step instructions

# %% [markdown]
# ## 4. Sentiment Scoring
# VADER compound score per post, hourly aggregate. DistilBERT (HuggingFace) for comparison. Create sentiment timeline.

# %%
# TODO: Implement Sentiment Scoring
# See README.md for full step-by-step instructions

# %% [markdown]
# ## 5. Topic Modeling
# BERTopic on all posts. Find: do topics shift before/after event? What do fans discuss most?

# %%
# TODO: Implement Topic Modeling
# See README.md for full step-by-step instructions

# %% [markdown]
# ## 6. Correlation Analysis
# Does pre-match sentiment predict match outcome? Pearson/Spearman — be honest about weak signal.

# %%
# TODO: Implement Correlation Analysis
# See README.md for full step-by-step instructions

# %% [markdown]
# ## Notes & Findings
# <!-- Fill in after running the notebook -->
#
# **Key finding:**
# _
#
# **Surprising result:**
# _
#
# **LinkedIn post angle:**
# _I analyzed Reddit after a blockbuster transfer announcement. Fan sentiment collapsed — then the team won 3 straight. The data is more interesting than the narrative._
