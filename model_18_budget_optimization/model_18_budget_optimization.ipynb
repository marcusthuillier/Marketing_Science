# %% [markdown]
# # Model 18 - Transfer Budget Allocation & Optimization
# **Discipline:** Growth DS
# **Question:** Given a fixed transfer budget, how should a club optimally allocate spend across positions to maximize expected points — and where does marginal return diminish?
# **Method:** Hill function saturation curves per position + constrained optimization (scipy/PuLP)
# **LinkedIn Hook:** MMM tells you what worked. Budget optimization tells you what to do next. I built both for football transfers. Most clubs are spending in completely the wrong places.

# %% [markdown]
# ## 0. Imports & Setup

# %%
import warnings
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

warnings.filterwarnings('ignore')
pd.set_option('display.max_columns', 50)

RANDOM_STATE = 42
OUTPUTS_DIR = 'outputs/'
print('All imports successful.')

# %% [markdown]
# ## 1. Data Collection
# Transfermarkt squad valuations for top 5 leagues. Group by position: GK, CB, FB, CM, AM, W, ST. FBref xG contribution per position.

# %%
# TODO: Implement Data Collection
# See README.md for full step-by-step instructions

# %% [markdown]
# ## 2. Response Curve Fitting
# For each position: squad value vs team xG contribution scatter. Fit Hill function: contribution = (investment^a) / (k^a + investment^a). Shows diminishing returns.

# %%
# TODO: Implement Response Curve Fitting
# See README.md for full step-by-step instructions

# %% [markdown]
# ## 3. Marginal Return Analysis
# Marginal xG per £1M at different investment levels. Find saturation point per position.

# %%
# TODO: Implement Marginal Return Analysis
# See README.md for full step-by-step instructions

# %% [markdown]
# ## 4. Optimization
# Objective: maximize xG - xGA. Constraint: total budget = £X. Solver: scipy.optimize or PuLP. Output: optimal £ per position.

# %%
# TODO: Implement Optimization
# See README.md for full step-by-step instructions

# %% [markdown]
# ## 5. Scenario Analysis
# Run for £50M, £100M, £200M. How does allocation strategy change with budget?

# %%
# TODO: Implement Scenario Analysis
# See README.md for full step-by-step instructions

# %% [markdown]
# ## 6. Validation
# Back-test: teams closest to optimal distribution — did they outperform? Which clubs are most wasteful?

# %%
# TODO: Implement Validation
# See README.md for full step-by-step instructions

# %% [markdown]
# ## Notes & Findings
# <!-- Fill in after running the notebook -->
#
# **Key finding:**
# _
#
# **Surprising result:**
# _
#
# **LinkedIn post angle:**
# _MMM tells you what worked. Budget optimization tells you what to do next. I built both for football transfers. Most clubs are spending in completely the wrong places._
