# %% [markdown]
# # Model 05 - Player LTV + CAC Modeling
# **Discipline:** Marketing DS + Growth DS
# **Question:** Can we predict a player's total career value from just their first 3 seasons — and which acquisition channel (draft vs free agent vs trade) offers the best LTV:CAC ratio?
# **Method:** Gradient Boosting regression for LTV prediction + LTV:CAC ratio analysis by acquisition channel

# %% [markdown]
# ## 0. Imports & Setup

# %%
# %matplotlib inline
from run_model_05 import (
    load_yearly_stats, aggregate_careers, compute_payback_curve,
    analyze_draft_slots, analyze_teams, generate_plots, print_findings,
)
print('Ready.')

# %% [markdown]
# ## 1. Data Loading

# %%
yearly = load_yearly_stats()

# %% [markdown]
# ## 2. Career Aggregation

# %%
career, merged = aggregate_careers(yearly)
merged.head(5)

# %% [markdown]
# ## 3. Payback Curve

# %%
payback_curve, payback_year = compute_payback_curve(merged, yearly)
payback_curve.head()

# %% [markdown]
# ## 4. Draft Slot Analysis

# %%
draft_r1, pick_analysis, has_draft = analyze_draft_slots()

# %% [markdown]
# ## 5. Team Analysis

# %%
mb_rank, all_time, team_yr = analyze_teams(yearly)

# %% [markdown]
# ## 6. Visualizations

# %%
generate_plots(merged, payback_curve, payback_year, pick_analysis, has_draft,
               mb_rank, all_time, team_yr, show=True)

# %% [markdown]
# ## Results
#
# **Key finding:**
# _
#
# **Surprising result:**
# _
