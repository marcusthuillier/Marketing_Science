# %% [markdown]
# # Model 13 - Goal Attribution Modeling
# **Discipline:** Marketing DS
# **Question:** When a goal is scored, who really deserves credit — and how radically does the answer change depending on which attribution model you use?
# **Method:** Last-touch vs Linear vs Shapley value attribution on StatsBomb event data
# **LinkedIn Hook:** Marketing attribution is broken. Football attribution has the exact same problem. I ran 3 models on the same goals — they disagreed by 400%. Here's why.

# %% [markdown]
# ## 0. Imports & Setup

# %%
import warnings
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

warnings.filterwarnings('ignore')
pd.set_option('display.max_columns', 50)

RANDOM_STATE = 42
OUTPUTS_DIR = 'outputs/'
print('All imports successful.')

# %% [markdown]
# ## 1. Data Collection
# StatsBomb free open data via statsbombpy. Focus: passes, carries, shots, goals. Reconstruct possession sequences leading to each goal.

# %%
# TODO: Implement Data Collection
# See README.md for full step-by-step instructions

# %% [markdown]
# ## 2. Possession Chain Reconstruction
# For each goal: trace back 10 events. Identify all players who touched the ball. Build: [player_a: 2 passes, player_b: 1 carry, player_c: assist, player_d: goal].

# %%
# TODO: Implement Possession Chain Reconstruction
# See README.md for full step-by-step instructions

# %% [markdown]
# ## 3. Last-Touch Attribution
# 100% credit to goal scorer. Baseline — represents last-click.

# %%
# TODO: Implement Last-Touch Attribution
# See README.md for full step-by-step instructions

# %% [markdown]
# ## 4. Linear Attribution
# Equal credit across all players in the possession chain, weighted by touches.

# %%
# TODO: Implement Linear Attribution
# See README.md for full step-by-step instructions

# %% [markdown]
# ## 5. Shapley Value Attribution
# Shapley value calculation per goal sequence. Treat each player's inclusion/exclusion as a coalition.

# %%
# TODO: Implement Shapley Value Attribution
# See README.md for full step-by-step instructions

# %% [markdown]
# ## 6. Comparison
# For 100 goals: how does credit distribution change? Which player is most undervalued by last-touch vs Shapley?

# %%
# TODO: Implement Comparison
# See README.md for full step-by-step instructions

# %% [markdown]
# ## Notes & Findings
# <!-- Fill in after running the notebook -->
#
# **Key finding:**
# _
#
# **Surprising result:**
# _
#
# **LinkedIn post angle:**
# _Marketing attribution is broken. Football attribution has the exact same problem. I ran 3 models on the same goals — they disagreed by 400%. Here's why._
