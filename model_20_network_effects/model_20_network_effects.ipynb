# %% [markdown]
# # Model 20 - Network Effects Modeling
# **Discipline:** Product DS
# **Question:** Do some players make everyone around them better — and can we quantify the network effect of adding a specific player to a lineup?
# **Method:** Passing network graph analysis (networkx) + NBA on/off lineup analysis + network multiplier score
# **LinkedIn Hook:** Network effects power the biggest tech platforms. I modeled them using passing networks. Some players make everyone around them dramatically better — you'd never guess who.

# %% [markdown]
# ## 0. Imports & Setup

# %%
import warnings
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

warnings.filterwarnings('ignore')
pd.set_option('display.max_columns', 50)

RANDOM_STATE = 42
OUTPUTS_DIR = 'outputs/'
print('All imports successful.')

# %% [markdown]
# ## 1. Data Collection
# StatsBomb free match data via statsbombpy. Extract all passes: passer, recipient, timestamp. Build adjacency matrix. Also: NBA lineup data via nba_api for on/off analysis.

# %%
# TODO: Implement Data Collection
# See README.md for full step-by-step instructions

# %% [markdown]
# ## 2. Passing Network Construction
# Per match: directed weighted graph (networkx). Nodes = players, edges = passes, weight = pass count. Normalize by time on pitch.

# %%
# TODO: Implement Passing Network Construction
# See README.md for full step-by-step instructions

# %% [markdown]
# ## 3. Graph Metrics
# Degree centrality. Betweenness centrality (sits on path between others). PageRank. Clustering coefficient.

# %%
# TODO: Implement Graph Metrics
# See README.md for full step-by-step instructions

# %% [markdown]
# ## 4. On/Off Analysis (NBA)
# Team offensive rating WITH vs WITHOUT each player. Network effect = change in teammates' stats when player is on court.

# %%
# TODO: Implement On/Off Analysis (NBA)
# See README.md for full step-by-step instructions

# %% [markdown]
# ## 5. Network Effect Score
# Combine: passing centrality + teammate performance lift. Normalize for team quality. Rank all players.

# %%
# TODO: Implement Network Effect Score
# See README.md for full step-by-step instructions

# %% [markdown]
# ## 6. Key Finding
# Players with highest network effect vs highest individual stats. Find the 'hidden connector': low individual stats, high network effect.

# %%
# TODO: Implement Key Finding
# See README.md for full step-by-step instructions

# %% [markdown]
# ## Notes & Findings
# <!-- Fill in after running the notebook -->
#
# **Key finding:**
# _
#
# **Surprising result:**
# _
#
# **LinkedIn post angle:**
# _Network effects power the biggest tech platforms. I modeled them using passing networks. Some players make everyone around them dramatically better — you'd never guess who._
