# %% [markdown]
# # Model 08 - EPL Standings Forecasting
# **Discipline:** Marketing DS + Growth DS
# **Question:** Which forecasting model best predicts final Premier League standings from mid-season data — and does a simple baseline beat the complex models?
# **Method:** Baseline extrapolation vs ARIMA vs Facebook Prophet — model horse race with RMSE comparison
# **LinkedIn Hook:** I tested 3 forecasting models on 10 seasons of EPL data. The simplest one won 7 out of 10 times. Here's why that matters for marketing forecasts.

# %% [markdown]
# ## 0. Imports & Setup

# %%
import warnings
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

warnings.filterwarnings('ignore')
pd.set_option('display.max_columns', 50)

RANDOM_STATE = 42
OUTPUTS_DIR = 'outputs/'
print('All imports successful.')

# %% [markdown]
# ## 1. Data Collection
# 10 seasons of EPL results from Football-Data.org. Rolling standings table: team points after each matchweek (1-38).

# %%
# TODO: Implement Data Collection
# See README.md for full step-by-step instructions

# %% [markdown]
# ## 2. Train/Test Setup
# For each season: train on matchweeks 1-19, forecast 20-38. Run for 10 seasons = 10 evaluation sets.

# %%
# TODO: Implement Train/Test Setup
# See README.md for full step-by-step instructions

# %% [markdown]
# ## 3. Baseline Model
# Points per game in first half × remaining games + home/away fixture adjustment. The benchmark everything must beat.

# %%
# TODO: Implement Baseline Model
# See README.md for full step-by-step instructions

# %% [markdown]
# ## 4. ARIMA Model
# Fit ARIMA on each team's points time series. statsmodels auto_arima for parameter selection.

# %%
# TODO: Implement ARIMA Model
# See README.md for full step-by-step instructions

# %% [markdown]
# ## 5. Prophet Model
# Treat each team's trajectory as a time series. Add title race pressure as binary regressor.

# %%
# TODO: Implement Prophet Model
# See README.md for full step-by-step instructions

# %% [markdown]
# ## 6. Comparison
# RMSE on final points + position accuracy. Does the baseline beat the complex models?

# %%
# TODO: Implement Comparison
# See README.md for full step-by-step instructions

# %% [markdown]
# ## Notes & Findings
# <!-- Fill in after running the notebook -->
#
# **Key finding:**
# _
#
# **Surprising result:**
# _
#
# **LinkedIn post angle:**
# _I tested 3 forecasting models on 10 seasons of EPL data. The simplest one won 7 out of 10 times. Here's why that matters for marketing forecasts._
