# %% [markdown]
# # Model 17 - Player Uplift Modeling
# **Discipline:** Growth DS
# **Question:** Which players actually respond to coaching interventions — and which would have improved regardless of what the coach did?
# **Method:** T-Learner meta-learner uplift model + propensity score matching + Qini curve evaluation
# **LinkedIn Hook:** Propensity asks 'who will improve?' Uplift asks 'who improves BECAUSE OF us?' Huge difference. I built an uplift model for football coaching. Some players are coachable. Most aren't.

# %% [markdown]
# ## 0. Imports & Setup

# %%
import warnings
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

warnings.filterwarnings('ignore')
pd.set_option('display.max_columns', 50)

RANDOM_STATE = 42
OUTPUTS_DIR = 'outputs/'
print('All imports successful.')

# %% [markdown]
# ## 1. Data Collection
# Players who experienced a manager change (treatment) vs comparable players who did not (control). Match on: position, age, prior stats, team strength.

# %%
# TODO: Implement Data Collection
# See README.md for full step-by-step instructions

# %% [markdown]
# ## 2. Treatment/Control Setup
# Treatment: manager changed mid-season or between seasons. Control: same profile, no manager change. Propensity score matching.

# %%
# TODO: Implement Treatment/Control Setup
# See README.md for full step-by-step instructions

# %% [markdown]
# ## 3. T-Learner Uplift Model
# Train separate models for treatment and control groups. Uplift = T-model prediction - C-model prediction.

# %%
# TODO: Implement T-Learner Uplift Model
# See README.md for full step-by-step instructions

# %% [markdown]
# ## 4. Player Segmentation
# Persuadables: improve because of intervention. Sure Things: improve regardless. Lost Causes: won't improve regardless. Sleeping Dogs: perform worse with intervention.

# %%
# TODO: Implement Player Segmentation
# See README.md for full step-by-step instructions

# %% [markdown]
# ## 5. Qini Curve
# Evaluate model: Qini curve vs random targeting baseline.

# %%
# TODO: Implement Qini Curve
# See README.md for full step-by-step instructions

# %% [markdown]
# ## 6. Insights
# Which positions respond most to manager changes? Does age predict responsiveness?

# %%
# TODO: Implement Insights
# See README.md for full step-by-step instructions

# %% [markdown]
# ## Notes & Findings
# <!-- Fill in after running the notebook -->
#
# **Key finding:**
# _
#
# **Surprising result:**
# _
#
# **LinkedIn post angle:**
# _Propensity asks 'who will improve?' Uplift asks 'who improves BECAUSE OF us?' Huge difference. I built an uplift model for football coaching. Some players are coachable. Most aren't._
